# %% [markdown]
# <a href="https://colab.research.google.com/github/mavericknihar/MachineLearning/blob/main/Basic%20Image%20Recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image
import numpy as np
from IPython.display import display

a = Image.open('/content/boy.png')
b = Image.open('/content/anadearmas.jpg')
i1 = np.array(a)
i2 = np.array(b)

def imageresize(im, sz):
    # Resizing an image using PIL
    pil_im = Image.fromarray(np.uint8(im))
    return np.array(pil_im.resize(sz))

a1 = Image.fromarray(i1)  # convert array1 to image
b1 = Image.fromarray(i2)  # convert array2 to image

display(a1)
display(b1)
# Out:
# <PIL.Image.Image image mode=L size=225x225>
# <PIL.Image.Image image mode=RGB size=183x275>

# %%
from PIL import Image
import numpy as np
from IPython.display import display

a = Image.open('/content/boy.png')
i1 = np.array(a)


def imageresize(im, sz):
    # Resizing an image using PIL
    pil_im = Image.fromarray(np.uint8(im))
    return np.array(pil_im.resize(sz))

a1 = Image.fromarray(i1)  # convert array1 to image


display(a1)
# Out:
# <PIL.Image.Image image mode=L size=225x225>

# %%
import PIL
